# %%
import numpy as np
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
images = np.load('../data/fold_1/images/fold1/images.npy')
types = np.load('../data/fold_1/images/fold1/types.npy')
masks = np.load('../data/fold_1/masks/fold1/masks.npy')

# %%
images.shape, types.shape, masks.shape
# Out:
# ((2656, 256, 256, 3), (2656,), (2656, 256, 256, 6))

# %%
plt.imshow(images[0]/ 255)

# %%
plt.imshow(masks[0,:,:,2])
